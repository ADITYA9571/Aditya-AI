# %% [markdown]
# File Input

# %%
file_name = input("Enter file name: ")

with open(file_name, "r", encoding="utf-8") as file:
    content = file.read()

print(content)

# %% [markdown]
# Exception Handling

# %%
file_name = input("Enter file name: ")

try:
    with open(file_name, "r", encoding="utf-8") as file:
        content = file.read()
        print(content)

except FileNotFoundError:
    print("File not found")

# %% [markdown]
# Command-Line Arguments

# %%
# Without sys.argv:
# The program stops and waits for the user to type something.
# With sys.argv:
# The filename is provided when starting the program as file_name = sys.argv[1]
import sys
print(sys.argv)

# %% [markdown]
# Functions

# %%
def count_words(text):
    return len(text.split())

print(count_words("Hello world"))

# %% [markdown]
# Dictionary

# %%
prices = {"gpt_4.o": 5.00,"gpt-4.1":0.40}
print(prices["gpt_4.o"])

# %% [markdown]
# Environment setup

# %%
# python -m venv env_name
# source env_name/Scripts/activate

# %% [markdown]
# Installing and Using a Library

# %%
import tiktoken
enc = tiktoken.encoding_for_model("gpt-4o")
tokens = enc.encode("Hello world")
print(len(tokens))

# %% [markdown]
# cost calculation

# %%
tokens = 1250
cost = 0.00625

print(f"Tokens: {tokens}")
print(f"Cost: ${cost:.4f}")
